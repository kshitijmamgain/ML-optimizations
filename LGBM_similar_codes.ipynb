# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading https://files.pythonhosted.org/packages/85/ee/2688cce5ced0597e12832d1ec4f4383a468f6bddff768eeaa3b5bf4f6500/optuna-1.3.0.tar.gz (163kB)
#      |████████████████████████████████| 163kB 2.7MB/s
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/60/1e/cabc75a189de0fbb2841d0975243e59bde8b7822bacbb95008ac6fe9ad47/alembic-1.4.2.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 30.2MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting cliff
#   Downloading https://files.pythonhosted.org/packages/b9/17/57187872842bf9f65815b6969b515528ec7fd754137d2d3f49e3bc016175/cliff-3.1.0-py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 11.2MB/s
# Collecting cmaes
#   Downloading https://files.pythonhosted.org/packages/a6/9f/9fcd62076df5ff38ac4678e819b23f374973214d94a678d417dbf03b9dc5/cmaes-0.3.2-py3-none-any.whl
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/00/0d/22c73c2eccb21dd3498df7d22c0b1d4a30f5a5fb3feb64e1ce06bc247747/colorlog-4.1.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (0.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.18.2)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.38.0)
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/50/78/f6ade1e18aebda570eed33b7c534378d9659351cadce2fcbc7b31be5f615/Mako-1.1.2-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 11.4MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.8.1)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.7.2)
# Requirement already satisfied: pyparsing>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (2.4.6)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.12.0)
# Collecting stevedore>=1.20.0
#   Downloading https://files.pythonhosted.org/packages/e6/49/a35dd566626892d577e426dbe5ea424dd7fbe10645f2c1070dcba474eca9/stevedore-1.32.0-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 8.0MB/s
# Collecting cmd2!=0.8.3,<0.9.0,>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/e9/40/a71caa2aaff10c73612a7106e2d35f693e85b8cf6e37ab0774274bca3cf9/cmd2-0.8.9-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 9.2MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/7a/db/a968fd7beb9fe06901c1841cb25c9ccb666ca1b9a19b114d1bbedf1126fc/pbr-5.4.4-py2.py3-none-any.whl (110kB)
#      |████████████████████████████████| 112kB 52.2MB/s
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Collecting pyperclip
#   Downloading https://files.pythonhosted.org/packages/f6/5b/55866e1cde0f86f5eec59dab5de8a66628cb0d53da74b8dbc15ad8dabda3/pyperclip-1.8.0.tar.gz
# Requirement already satisfied: wcwidth; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,<0.9.0,>=0.8.0->cliff->optuna) (0.1.9)
# Building wheels for collected packages: alembic
#   Building wheel for alembic (PEP 517) ... done
#   Created wheel for alembic: filename=alembic-1.4.2-cp36-none-any.whl size=159543 sha256=40d1b3e3ebaf5f662364b83c2907d9d6cf0ee737035c84e8225dbb443c5fab67
#   Stored in directory: /root/.cache/pip/wheels/1f/04/83/76023f7a4c14688c0b5c2682a96392cfdd3ee4449eaaa287ef
# Successfully built alembic
# Building wheels for collected packages: optuna, pyperclip
#   Building wheel for optuna (setup.py) ... done
#   Created wheel for optuna: filename=optuna-1.3.0-cp36-none-any.whl size=221121 sha256=70ac1fb8246e2c158d53e4ea1dc9296e6ed6f0779e0e08ed8c3a813161c1673f
#   Stored in directory: /root/.cache/pip/wheels/62/fd/dd/71cfd4cee14164152b952f477a16dac42ba413cfb1981585e4
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.0-cp36-none-any.whl size=8693 sha256=28116814b28dbbae96fb9386432050eae6e6cd1051f475adf6caf00b9a69cca2
#   Stored in directory: /root/.cache/pip/wheels/b2/ac/0a/b784f0afe26eaf52e88a7e15c7369090deea0354fa1c6fc689
# Successfully built optuna pyperclip
# Installing collected packages: python-editor, Mako, alembic, pbr, stevedore, pyperclip, cmd2, cliff, cmaes, colorlog, optuna
# Successfully installed Mako-1.1.2 alembic-1.4.2 cliff-3.1.0 cmaes-0.3.2 cmd2-0.8.9 colorlog-4.1.0 optuna-1.3.0 pbr-5.4.4 pyperclip-1.8.0 python-editor-1.0.4 stevedore-1.32.0

# %%
# import dependent libraries

'''
#reference links
Hyperopt and Randomsearch with early stopping https://github.com/WillKoehrsen/hyperparameter-optimization 
Optuna tuner https://github.com/optuna/optuna/blob/master/examples/lightgbm_tuner_simple.py
'''

import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import auc, accuracy_score, roc_auc_score, roc_curve
from sklearn.model_selection import RandomizedSearchCV

import csv
from timeit import default_timer as timer
from hyperopt import STATUS_OK, hp, tpe, Trials, fmin
from hyperopt.pyll.stochastic import sample
import random

import optuna.integration.lightgbm as lgbo
import optuna

# %%
# starting with storing the data as data frame
df = pd.read_csv("drive/My Drive/Colab Notebooks/train_test_files_sample.csv")
df.drop( columns='Unnamed: 0', inplace =True)

# making a smaller df for quick testing
df_s, _ = train_test_split(df, random_state = 30, train_size = 0.01)

train_X = df_s.drop(columns = '0')
train_y = df_s['0']

# %%
# drop last columns

def col_keep(df):
  return df.drop(columns = list(map(str,range(22,29))), inplace = True) # removing 7 last columns

# %%
MAX_EVALS = 5
N_FOLDS = 3

# %% [markdown]
# # Hyperopt

# %%
def objective(params, n_folds = N_FOLDS):
    """Objective function for Gradient Boosting Machine Hyperparameter Optimization"""
    
    # Keep track of evals
    global ITERATION
    
    ITERATION += 1
    
    # Retrieve the subsample if present otherwise set to 1.0
    subsample = params['boosting_type'].get('subsample', 1.0)
    
    # Extract the boosting type
    params['boosting_type'] = params['boosting_type']['boosting_type']
    params['subsample'] = subsample
    
    # Make sure parameters that need to be integers are integers
    for parameter_name in ['num_leaves', 'subsample_for_bin', 'min_data_in_leaf', 
                           'max_bin', 'bagging_freq']:
        params[parameter_name] = int(params[parameter_name])
    
    start = timer()
    
    # Perform n_folds cross validation
    cv_results = lgb.cv(params, train_set, num_boost_round = 10000, nfold = n_folds, 
                        early_stopping_rounds = 100, metrics = 'auc', seed = 50)
    
    run_time = timer() - start
    
    # Extract the best score
    best_score = np.max(cv_results['auc-mean'])
    
    # Loss must be minimized
    loss = 1 - best_score
    
    # Boosting rounds that returned the highest cv score
    n_estimators = int(np.argmax(cv_results['auc-mean']) + 1)

    # Write to the csv file ('a' means append)
    of_connection = open(out_file, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([loss, params, ITERATION, n_estimators, run_time])
    
    # Dictionary with information for evaluation
    return {'loss': loss, 'params': params, 'iteration': ITERATION,
            'estimators': n_estimators, 
            'train_time': run_time, 'status': STATUS_OK}


# Hyperopt Space
space = {              
            'num_leaves': hp.quniform('num_leaves', 16, 196, 4),

            'max_bin' : hp.quniform('max_bin', 254, 254, 1), #if using CPU just set this to 254

            'lambda_l1': hp.loguniform('lambda_l1', 1e-8, 10.0),
            
            'lambda_l2': hp.loguniform("lambda_l2", 1e-8, 10.0),
            
            'min_data_in_leaf' : hp.quniform('min_data_in_leaf', 20, 500, 10),

            'class_weight': hp.choice('class_weight', [None, 'balanced']),
            
            'boosting_type': hp.choice('boosting_type', [{'boosting_type': 'gbdt', 'subsample': hp.uniform('gdbt_subsample', 0.5, 1)}, 
                                                         {'boosting_type': 'dart', 'subsample': hp.uniform('dart_subsample', 0.5, 1)},
                                                         {'boosting_type': 'goss', 'subsample': 1.0}]),

            'learning_rate' : hp.loguniform('learning_rate', np.log(0.05), np.log(0.25)),

            'subsample_for_bin': hp.quniform('subsample_for_bin', 20000, 300000, 20000),

            'feature_fraction': hp.uniform('feature_fraction', 0.4, 1.0),
                     
            'bagging_freq': hp.uniform('bagging_freq', 1, 7),
                     
            'verbosity' : 0

        }

# optimization algorithm
tpe_algorithm = tpe.suggest

# Keep track of results
bayes_trials = Trials()

# File to save first results
out_file = 'gbm_trials.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)

# Write the headers to the file
writer.writerow(['loss', 'params', 'iteration', 'estimators', 'train_time'])
of_connection.close()

# Global variable
global  ITERATION

ITERATION = 0

train_set = lgb.Dataset(data=train_X, label = train_y)

# Run optimization
best = fmin(fn = objective, space = space, algo = tpe.suggest, 
            max_evals = 100, trials = bayes_trials, rstate = np.random.RandomState(50))
# Out:
#   1%|          | 1/100 [00:00<00:54,  1.81it/s, best loss: 0.5]
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
#  10%|█         | 10/100 [00:45<02:56,  1.96s/it, best loss: 0.22370190630097253]
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
#  14%|█▍        | 14/100 [01:23<06:42,  4.68s/it, best loss: 0.22370190630097253]
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
#  19%|█▉        | 19/100 [12:08<1:04:03, 47.45s/it, best loss: 0.21762932573434635]
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
#  20%|██        | 20/100 [12:46<51:05, 38.32s/it, best loss: 0.21762932573434635]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-78-1d4a4b3bb16c> in <module>()
#     101 # Run optimization
#     102 best = fmin(fn = objective, space = space, algo = tpe.suggest,
# --> 103             max_evals = 100, trials = bayes_trials, rstate = np.random.RandomState(50))
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     386             catch_eval_exceptions=catch_eval_exceptions,
#     387             return_argmin=return_argmin,
# --> 388             show_progressbar=show_progressbar,
#     389         )
#     390
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     637             catch_eval_exceptions=catch_eval_exceptions,
#     638             return_argmin=return_argmin,
# --> 639             show_progressbar=show_progressbar)
#     640
#     641
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     209                                                           d['result'].get('status')))
#     210                         new_trials = algo(new_ids, self.domain, trials,
# --> 211                                           self.rstate.randint(2 ** 31 - 1))
#     212                         assert len(new_ids) >= len(new_trials)
#     213                         if len(new_trials):
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/tpe.py in suggest(new_ids, domain, trials, seed, prior_weight, n_startup_jobs, n_EI_candidates, gamma, linear_forgetting)
#     898
#     899     idxs, vals = pyll.rec_eval([opt_idxs, opt_vals], memo=memo,
# --> 900                                print_node_on_error=False)
#     901
#     902     # -- retrieve the best of the samples and form the return tuple
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/pyll/base.py in rec_eval(expr, deepcopy_inputs, memo, max_program_len, memo_gc, print_trace, print_node_on_error)
#     911
#     912             try:
# --> 913                 rval = scope._impls[node.name](*args, **kwargs)
#     914
#     915             except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/tpe.py in adaptive_parzen_normal(mus, prior_weight, prior_mu, prior_sigma, LF)
#     463
#     464     sigma[prior_pos] = prior_sigma
# --> 465     assert prior_sigma > 0
#     466     assert maxsigma > 0
#     467     assert minsigma > 0
#
# AssertionError:

# %% [markdown]
# # Random Search

# %%
def random_objective(params, iteration, n_folds = N_FOLDS):
    """Random search objective function. Takes in hyperparameters
       and returns a list of results to be saved."""

    start = timer()
    # Subsampling (only applicable with 'goss')
    subsample_dist = list(np.linspace(0.5, 1, 100))

    if params['boosting_type'] == 'goss':
        # Cannot subsample with goss
        params['subsample'] = 1.0
    else:
        # Subsample supported for gdbt and dart
        params['subsample'] = random.sample(subsample_dist, 1)[0]    

    # Perform n_folds cross validation
    cv_results = lgb.cv(params, train_set, num_boost_round = 1000, nfold = n_folds, 
                        early_stopping_rounds = 100, metrics = 'auc', seed = 50)
    end = timer()
    best_score = np.max(cv_results['auc-mean'])
    
    # Loss must be minimized
    loss = 1 - best_score
    
    # Boosting rounds that returned the highest cv score
    n_estimators = int(np.argmax(cv_results['auc-mean']) + 1)
    
    # Return list of results
    return [loss, params, iteration, n_estimators, end - start]

# Hyperparameter grid
param_grid = {
                'num_leaves': list(range(16, 196, 4)),
              
                'max_bin': [254],

                'lambda_l1': list(np.linspace(0, 1)),

                'lambda_l2': list(np.linspace(0, 1)),

                'min_data_in_leaf' : list(range(20, 500, 10)),

                'class_weight': [None, 'balanced'],

                'boosting_type': ['gbdt', 'goss', 'dart'],
              
                'learning_rate' : list(np.logspace(np.log(0.05), np.log(0.2), base = np.exp(1), num = 1000)),

                'feature_fraction': list(np.linspace(0.4, 1.0)),

                'bagging_freq': list(range(1,7)),

                'verbosity' : [0]
                }

random.seed(50)

# Dataframe to hold cv results
random_results = pd.DataFrame(columns = ['loss', 'params', 'iteration', 'estimators', 'time'],
                       index = list(range(MAX_EVALS)))

# Iterate through the specified number of evaluations
for i in range(15):
    
    # Randomly sample parameters for gbm
    params = {key: random.sample(value, 1)[0] for key, value in param_grid.items()}
    
    print(params)  
        
    results_list = random_objective(params, i)
    
    # Add results to next row in dataframe
    random_results.loc[i, :] = results_list
# Out:
# {'num_leaves': 140, 'max_bin': 254, 'lambda_l1': 0.4693877551020408, 'lambda_l2': 0.8163265306122448, 'min_data_in_leaf': 170, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.05641591746163987, 'feature_fraction': 0.8163265306122449, 'bagging_freq': 3, 'verbosity': 0}
# {'num_leaves': 188, 'max_bin': 254, 'lambda_l1': 0.18367346938775508, 'lambda_l2': 0.44897959183673464, 'min_data_in_leaf': 80, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.06851322752809227, 'feature_fraction': 0.5469387755102041, 'bagging_freq': 1, 'verbosity': 0}
# {'num_leaves': 168, 'max_bin': 254, 'lambda_l1': 0.8163265306122448, 'lambda_l2': 0.1020408163265306, 'min_data_in_leaf': 60, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.12460114426637409, 'feature_fraction': 0.7306122448979592, 'bagging_freq': 1, 'verbosity': 0}
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
# {'num_leaves': 84, 'max_bin': 254, 'lambda_l1': 0.8979591836734693, 'lambda_l2': 0.12244897959183673, 'min_data_in_leaf': 140, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.18098320907845356, 'feature_fraction': 0.9387755102040817, 'bagging_freq': 5, 'verbosity': 0}
# {'num_leaves': 48, 'max_bin': 254, 'lambda_l1': 0.7959183673469387, 'lambda_l2': 0.26530612244897955, 'min_data_in_leaf': 360, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.13171296819007705, 'feature_fraction': 0.8775510204081632, 'bagging_freq': 6, 'verbosity': 0}
# {'num_leaves': 176, 'max_bin': 254, 'lambda_l1': 0.5510204081632653, 'lambda_l2': 0.673469387755102, 'min_data_in_leaf': 360, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.11244107634796272, 'feature_fraction': 0.8040816326530612, 'bagging_freq': 3, 'verbosity': 0}
# {'num_leaves': 108, 'max_bin': 254, 'lambda_l1': 0.0, 'lambda_l2': 0.44897959183673464, 'min_data_in_leaf': 20, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.15364700228249017, 'feature_fraction': 0.9020408163265307, 'bagging_freq': 5, 'verbosity': 0}
# {'num_leaves': 56, 'max_bin': 254, 'lambda_l1': 0.16326530612244897, 'lambda_l2': 0.32653061224489793, 'min_data_in_leaf': 260, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.052415596747708335, 'feature_fraction': 0.889795918367347, 'bagging_freq': 5, 'verbosity': 0}
# {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 0.8775510204081632, 'lambda_l2': 0.32653061224489793, 'min_data_in_leaf': 350, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.11353862562875072, 'feature_fraction': 0.7183673469387755, 'bagging_freq': 4, 'verbosity': 0}
# {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 0.14285714285714285, 'lambda_l2': 0.4693877551020408, 'min_data_in_leaf': 50, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.09388124692632276, 'feature_fraction': 0.9142857142857143, 'bagging_freq': 6, 'verbosity': 0}
# {'num_leaves': 96, 'max_bin': 254, 'lambda_l1': 0.6938775510204082, 'lambda_l2': 0.836734693877551, 'min_data_in_leaf': 450, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.07666375756435229, 'feature_fraction': 0.5224489795918368, 'bagging_freq': 4, 'verbosity': 0}
# {'num_leaves': 184, 'max_bin': 254, 'lambda_l1': 0.0, 'lambda_l2': 0.2040816326530612, 'min_data_in_leaf': 100, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.052125458003749424, 'feature_fraction': 0.6326530612244898, 'bagging_freq': 6, 'verbosity': 0}
# {'num_leaves': 60, 'max_bin': 254, 'lambda_l1': 0.3061224489795918, 'lambda_l2': 0.7551020408163265, 'min_data_in_leaf': 470, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.1154451213771475, 'feature_fraction': 0.4122448979591837, 'bagging_freq': 2, 'verbosity': 0}
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
# {'num_leaves': 124, 'max_bin': 254, 'lambda_l1': 0.6938775510204082, 'lambda_l2': 0.18367346938775508, 'min_data_in_leaf': 160, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.11803700655197771, 'feature_fraction': 0.6204081632653061, 'bagging_freq': 6, 'verbosity': 0}
# /usr/local/lib/python3.6/dist-packages/lightgbm/callback.py:189: UserWarning:
#
# Early stopping is not available in dart mode
# {'num_leaves': 96, 'max_bin': 254, 'lambda_l1': 0.18367346938775508, 'lambda_l2': 0.6938775510204082, 'min_data_in_leaf': 320, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.15731471815103718, 'feature_fraction': 0.48571428571428577, 'bagging_freq': 3, 'verbosity': 0}

# %% [markdown]
# # Optuna

# %%
def objective(trial):
    
    dtrain = lgbo.Dataset(train_X, label=train_y)

    global ITERATION_O

    ITERATION_O += 1

    param ={              
            'num_leaves': trial.suggest_int('num_leaves', 16, 196, 4),

            'max_bin' : trial.suggest_uniform('max_bin', 254, 254), #if using CPU just set this to 254

            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            
            'lambda_l2': trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
            
            'min_data_in_leaf' : trial.suggest_int('min_data_in_leaf', 20, 500),

            'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced']),
            
            'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart', 'goss']),

            'learning_rate' : trial.suggest_loguniform('learning_rate', 0.05, 0.25),

            'feature_fraction': trial.suggest_uniform("feature_fraction", 0.4, 1.0),
                
            'bagging_freq': trial.suggest_int("bagging_freq", 1, 7),
                     
            'verbosity' : 0

        }
    
    start = timer()
    # Perform n_folds cross validation
    if param['boosting_type'] == 'goss':
      param['subsample'] = 1
    else:
      param['subsample'] = trial.suggest_uniform('subsample', 0.5, 1)
    
    cv_results = lgb.cv(params, train_set, num_boost_round = 10000, nfold = 3, 
                        early_stopping_rounds = 100, metrics = 'auc', seed = 50)
    
    run_time = timer() - start
    
    # Extract the best score
    best_score = np.max(cv_results['auc-mean'])

    loss = 1 - best_score

    # Boosting rounds that returned the highest cv score
    n_estimators = int(np.argmax(cv_results['auc-mean']) + 1)

    # Write to the csv file ('a' means append)
    of_connection = open(out_file, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([loss, param, ITERATION, n_estimators, run_time])

    
    return loss

# Global variable
global  ITERATION_O

ITERATION_O = 0

# File to save first results
out_file = 'gbm_optuna.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)

# Write the headers to the file
writer.writerow(['loss', 'params', 'iteration', 'estimators', 'train_time'])
of_connection.close()

study = optuna.create_study(direction='minimize')

study.optimize(objective, n_trials=5000)
# Out:
# [I 2020-04-02 17:57:25,374] Finished trial#0 with value: 0.22092658226241424 with parameters: {'num_leaves': 60, 'max_bin': 254, 'lambda_l1': 2.4569464506213583e-06, 'lambda_l2': 0.00180884407558789, 'min_data_in_leaf': 91, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.19258450886769526, 'feature_fraction': 0.8148468683250664, 'bagging_freq': 7, 'subsample': 0.6048199922164568}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:26,966] Finished trial#1 with value: 0.22092658226241424 with parameters: {'num_leaves': 156, 'max_bin': 254, 'lambda_l1': 2.0978256504871975e-07, 'lambda_l2': 2.218610749344635e-08, 'min_data_in_leaf': 331, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.1422788757978464, 'feature_fraction': 0.8053325542084108, 'bagging_freq': 7, 'subsample': 0.6441387756094226}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:28,575] Finished trial#2 with value: 0.22092658226241424 with parameters: {'num_leaves': 20, 'max_bin': 254, 'lambda_l1': 0.028576970326287084, 'lambda_l2': 0.005533107505235895, 'min_data_in_leaf': 27, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.13102248382679196, 'feature_fraction': 0.5552490280047616, 'bagging_freq': 2, 'subsample': 0.7400511348407239}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:30,173] Finished trial#3 with value: 0.22092658226241424 with parameters: {'num_leaves': 20, 'max_bin': 254, 'lambda_l1': 8.687413728469199, 'lambda_l2': 6.243772698430461e-05, 'min_data_in_leaf': 168, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.11025732252684671, 'feature_fraction': 0.8631006213962644, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:31,805] Finished trial#4 with value: 0.22092658226241424 with parameters: {'num_leaves': 100, 'max_bin': 254, 'lambda_l1': 4.193671792799466, 'lambda_l2': 0.0793951947773618, 'min_data_in_leaf': 208, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.22088644411100217, 'feature_fraction': 0.9597620471891255, 'bagging_freq': 6}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:33,450] Finished trial#5 with value: 0.22092658226241424 with parameters: {'num_leaves': 64, 'max_bin': 254, 'lambda_l1': 1.0762897110112637e-08, 'lambda_l2': 0.0017259768404141302, 'min_data_in_leaf': 203, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.059250557335889034, 'feature_fraction': 0.553581980260388, 'bagging_freq': 3, 'subsample': 0.7445301868294386}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:35,070] Finished trial#6 with value: 0.22092658226241424 with parameters: {'num_leaves': 196, 'max_bin': 254, 'lambda_l1': 3.176565475560278e-08, 'lambda_l2': 1.0094533370207677e-05, 'min_data_in_leaf': 236, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.12505465243844419, 'feature_fraction': 0.415104571367433, 'bagging_freq': 7, 'subsample': 0.9194519672257977}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:36,676] Finished trial#7 with value: 0.22092658226241424 with parameters: {'num_leaves': 88, 'max_bin': 254, 'lambda_l1': 0.021927849229186353, 'lambda_l2': 1.6737869263516134e-07, 'min_data_in_leaf': 434, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.13094400195445977, 'feature_fraction': 0.735987026265168, 'bagging_freq': 7}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:38,248] Finished trial#8 with value: 0.22092658226241424 with parameters: {'num_leaves': 156, 'max_bin': 254, 'lambda_l1': 0.002115388945025794, 'lambda_l2': 0.0013314634557773932, 'min_data_in_leaf': 419, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.10222398350860583, 'feature_fraction': 0.6944768650051025, 'bagging_freq': 4, 'subsample': 0.5865474466059151}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:39,770] Finished trial#9 with value: 0.22092658226241424 with parameters: {'num_leaves': 180, 'max_bin': 254, 'lambda_l1': 5.393646224947337, 'lambda_l2': 4.173149727977945e-06, 'min_data_in_leaf': 173, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.10645848135828379, 'feature_fraction': 0.9544506436951378, 'bagging_freq': 3, 'subsample': 0.7533840691722469}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:41,331] Finished trial#10 with value: 0.22092658226241424 with parameters: {'num_leaves': 56, 'max_bin': 254, 'lambda_l1': 3.7183754102549406e-06, 'lambda_l2': 8.163937607552944, 'min_data_in_leaf': 51, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.24339188476746243, 'feature_fraction': 0.6317936304505728, 'bagging_freq': 5, 'subsample': 0.8456017076410784}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:42,871] Finished trial#11 with value: 0.22092658226241424 with parameters: {'num_leaves': 140, 'max_bin': 254, 'lambda_l1': 2.186451991966718e-06, 'lambda_l2': 0.489408446568656, 'min_data_in_leaf': 338, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.18193343458690214, 'feature_fraction': 0.8210560273577706, 'bagging_freq': 7, 'subsample': 0.6008213884076123}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:44,439] Finished trial#12 with value: 0.22092658226241424 with parameters: {'num_leaves': 120, 'max_bin': 254, 'lambda_l1': 1.578078355356633e-06, 'lambda_l2': 2.6338592515710988e-08, 'min_data_in_leaf': 329, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.17288525630904014, 'feature_fraction': 0.8308183016491275, 'bagging_freq': 6, 'subsample': 0.6113537652859193}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:45,999] Finished trial#13 with value: 0.22092658226241424 with parameters: {'num_leaves': 56, 'max_bin': 254, 'lambda_l1': 1.390459691956983e-07, 'lambda_l2': 7.39073239176814e-07, 'min_data_in_leaf': 77, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.07946355869006694, 'feature_fraction': 0.7561470472530828, 'bagging_freq': 6, 'subsample': 0.5035330762465886}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:47,515] Finished trial#14 with value: 0.22092658226241424 with parameters: {'num_leaves': 164, 'max_bin': 254, 'lambda_l1': 3.454399772601228e-05, 'lambda_l2': 9.555632047226337e-05, 'min_data_in_leaf': 329, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.17862134716280378, 'feature_fraction': 0.891381162427567, 'bagging_freq': 5, 'subsample': 0.51584587461103}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:49,039] Finished trial#15 with value: 0.22092658226241424 with parameters: {'num_leaves': 128, 'max_bin': 254, 'lambda_l1': 0.00013640361927977357, 'lambda_l2': 0.06832045006987357, 'min_data_in_leaf': 499, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.15151898169947942, 'feature_fraction': 0.7823546933382924, 'bagging_freq': 1, 'subsample': 0.6683459221126161}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:50,549] Finished trial#16 with value: 0.22092658226241424 with parameters: {'num_leaves': 80, 'max_bin': 254, 'lambda_l1': 1.9020895510689876e-07, 'lambda_l2': 1.920160464672924e-08, 'min_data_in_leaf': 113, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.22070973023990575, 'feature_fraction': 0.672145694834521, 'bagging_freq': 7, 'subsample': 0.6861138903635189}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:52,056] Finished trial#17 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 4.364712421051049e-05, 'lambda_l2': 0.00018823344937464256, 'min_data_in_leaf': 282, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.18950198776636115, 'feature_fraction': 0.9055208019899961, 'bagging_freq': 5, 'subsample': 0.5445336108203517}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:53,585] Finished trial#18 with value: 0.22092658226241424 with parameters: {'num_leaves': 120, 'max_bin': 254, 'lambda_l1': 0.0005482731836691036, 'lambda_l2': 0.036327431199999295, 'min_data_in_leaf': 499, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.15751405458359338, 'feature_fraction': 0.9948541565199205, 'bagging_freq': 1, 'subsample': 0.6579459173741248}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:55,154] Finished trial#19 with value: 0.22092658226241424 with parameters: {'num_leaves': 80, 'max_bin': 254, 'lambda_l1': 1.9163112703116545e-07, 'lambda_l2': 2.0192861248320515, 'min_data_in_leaf': 113, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.24247370055611134, 'feature_fraction': 0.6572685759964288, 'bagging_freq': 6, 'subsample': 0.8327831463502787}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:56,701] Finished trial#20 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.1345991572216956e-05, 'lambda_l2': 0.00028269091724482105, 'min_data_in_leaf': 277, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.20276407392772736, 'feature_fraction': 0.920660471499814, 'bagging_freq': 5}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:58,258] Finished trial#21 with value: 0.22092658226241424 with parameters: {'num_leaves': 32, 'max_bin': 254, 'lambda_l1': 0.0013821289604103082, 'lambda_l2': 0.0102712348000662, 'min_data_in_leaf': 493, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.161233075525251, 'feature_fraction': 0.9891518659069313, 'bagging_freq': 1, 'subsample': 0.5490227105406104}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:57:59,845] Finished trial#22 with value: 0.22092658226241424 with parameters: {'num_leaves': 80, 'max_bin': 254, 'lambda_l1': 0.0006507851488650254, 'lambda_l2': 6.222629187798282, 'min_data_in_leaf': 119, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.24863358168155378, 'feature_fraction': 0.5523875233891311, 'bagging_freq': 6, 'subsample': 0.7032518010811207}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:01,541] Finished trial#23 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.1343098776200345e-05, 'lambda_l2': 1.1388865546301579, 'min_data_in_leaf': 279, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.21267845018770912, 'feature_fraction': 0.6173974301814267, 'bagging_freq': 5}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:03,118] Finished trial#24 with value: 0.22092658226241424 with parameters: {'num_leaves': 32, 'max_bin': 254, 'lambda_l1': 0.04149189730016587, 'lambda_l2': 0.005110603246074837, 'min_data_in_leaf': 442, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.2015219599742152, 'feature_fraction': 0.9324532441144253, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:04,688] Finished trial#25 with value: 0.22092658226241424 with parameters: {'num_leaves': 72, 'max_bin': 254, 'lambda_l1': 0.0029098537455281045, 'lambda_l2': 0.017038885152837562, 'min_data_in_leaf': 126, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.24746857253106883, 'feature_fraction': 0.42083513644928516, 'bagging_freq': 2, 'subsample': 0.8283865899686844}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:06,391] Finished trial#26 with value: 0.22092658226241424 with parameters: {'num_leaves': 52, 'max_bin': 254, 'lambda_l1': 0.00016484810039515553, 'lambda_l2': 6.215463157632939, 'min_data_in_leaf': 75, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.2493659343731083, 'feature_fraction': 0.5829952704194575, 'bagging_freq': 6}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:07,917] Finished trial#27 with value: 0.22092658226241424 with parameters: {'num_leaves': 16, 'max_bin': 254, 'lambda_l1': 0.164509797140503, 'lambda_l2': 0.22610124725338931, 'min_data_in_leaf': 384, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.20569843006267, 'feature_fraction': 0.7285874423671047, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:09,338] Finished trial#28 with value: 0.22092658226241424 with parameters: {'num_leaves': 68, 'max_bin': 254, 'lambda_l1': 0.41617411331283455, 'lambda_l2': 0.00108238509185634, 'min_data_in_leaf': 146, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.09572439776650923, 'feature_fraction': 0.43961783924815073, 'bagging_freq': 2, 'subsample': 0.5659717716406796}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:10,759] Finished trial#29 with value: 0.22092658226241424 with parameters: {'num_leaves': 100, 'max_bin': 254, 'lambda_l1': 0.00411640175162574, 'lambda_l2': 1.1110579647435121e-05, 'min_data_in_leaf': 20, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.24101380297437242, 'feature_fraction': 0.477786652204486, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:12,195] Finished trial#30 with value: 0.22092658226241424 with parameters: {'num_leaves': 20, 'max_bin': 254, 'lambda_l1': 0.3749158621978784, 'lambda_l2': 0.2871034892559005, 'min_data_in_leaf': 390, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.05007634065175153, 'feature_fraction': 0.5947287809647205, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:13,618] Finished trial#31 with value: 0.22092658226241424 with parameters: {'num_leaves': 56, 'max_bin': 254, 'lambda_l1': 0.13900132274945443, 'lambda_l2': 0.1619261838413745, 'min_data_in_leaf': 65, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.09186651678162527, 'feature_fraction': 0.48115112219739653, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:15,093] Finished trial#32 with value: 0.22092658226241424 with parameters: {'num_leaves': 96, 'max_bin': 254, 'lambda_l1': 0.8963750157741291, 'lambda_l2': 2.296719931703908e-05, 'min_data_in_leaf': 39, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.07593395116942613, 'feature_fraction': 0.4593800671002553, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:16,527] Finished trial#33 with value: 0.22092658226241424 with parameters: {'num_leaves': 112, 'max_bin': 254, 'lambda_l1': 1.0639374165043618, 'lambda_l2': 0.0009344203660107539, 'min_data_in_leaf': 20, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.0593039752594121, 'feature_fraction': 0.5045538426983484, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:17,961] Finished trial#34 with value: 0.22092658226241424 with parameters: {'num_leaves': 24, 'max_bin': 254, 'lambda_l1': 0.009949047894179336, 'lambda_l2': 2.0251753645913515e-06, 'min_data_in_leaf': 82, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.07838414858539491, 'feature_fraction': 0.5083291516747289, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:19,394] Finished trial#35 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 3.55068932314791e-07, 'lambda_l2': 0.008905733706110771, 'min_data_in_leaf': 185, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.1610138812318741, 'feature_fraction': 0.8560878435327961, 'bagging_freq': 6, 'subsample': 0.6905346100851212}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:20,827] Finished trial#36 with value: 0.22092658226241424 with parameters: {'num_leaves': 28, 'max_bin': 254, 'lambda_l1': 0.0005742138644337263, 'lambda_l2': 0.00038259100685677426, 'min_data_in_leaf': 236, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.14553856040733829, 'feature_fraction': 0.9764700612194367, 'bagging_freq': 5, 'subsample': 0.8554993387144642}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:22,263] Finished trial#37 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 1.3393278123915771e-05, 'lambda_l2': 0.004164430496952023, 'min_data_in_leaf': 149, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.12010162891509883, 'feature_fraction': 0.9118538607153419, 'bagging_freq': 7, 'subsample': 0.95561343265509}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:23,708] Finished trial#38 with value: 0.22092658226241424 with parameters: {'num_leaves': 76, 'max_bin': 254, 'lambda_l1': 0.0007523858851303204, 'lambda_l2': 1.4878131170375961, 'min_data_in_leaf': 243, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.2210172775420981, 'feature_fraction': 0.5476628252893373, 'bagging_freq': 6, 'subsample': 0.5737683361125172}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:25,179] Finished trial#39 with value: 0.22092658226241424 with parameters: {'num_leaves': 92, 'max_bin': 254, 'lambda_l1': 7.666775595477212e-05, 'lambda_l2': 1.2999917042924376, 'min_data_in_leaf': 476, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.16903730689193275, 'feature_fraction': 0.6107756071433561, 'bagging_freq': 7, 'subsample': 0.7926689514875795}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:26,639] Finished trial#40 with value: 0.22092658226241424 with parameters: {'num_leaves': 60, 'max_bin': 254, 'lambda_l1': 8.55953807351001e-06, 'lambda_l2': 8.91641326606146, 'min_data_in_leaf': 461, 'class_weight': 'balanced', 'boosting_type': 'goss', 'learning_rate': 0.19971963803856083, 'feature_fraction': 0.6398974299129622, 'bagging_freq': 5}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:28,156] Finished trial#41 with value: 0.22092658226241424 with parameters: {'num_leaves': 68, 'max_bin': 254, 'lambda_l1': 0.03669486411253571, 'lambda_l2': 0.014123872298317573, 'min_data_in_leaf': 111, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.22358402835430216, 'feature_fraction': 0.418454209096915, 'bagging_freq': 3, 'subsample': 0.9783842598093545}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:29,698] Finished trial#42 with value: 0.22092658226241424 with parameters: {'num_leaves': 48, 'max_bin': 254, 'lambda_l1': 0.00015706194302147783, 'lambda_l2': 0.02471974598651112, 'min_data_in_leaf': 143, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.21857023197939232, 'feature_fraction': 0.7098563178332509, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:31,214] Finished trial#43 with value: 0.22092658226241424 with parameters: {'num_leaves': 52, 'max_bin': 254, 'lambda_l1': 7.802066083796392e-07, 'lambda_l2': 0.003086965477166709, 'min_data_in_leaf': 90, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.19138300555806778, 'feature_fraction': 0.602604659208702, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:32,738] Finished trial#44 with value: 0.22092658226241424 with parameters: {'num_leaves': 20, 'max_bin': 254, 'lambda_l1': 0.05230155209290734, 'lambda_l2': 0.08598865734385704, 'min_data_in_leaf': 380, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.24794812758215504, 'feature_fraction': 0.7929481912795534, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:34,253] Finished trial#45 with value: 0.22092658226241424 with parameters: {'num_leaves': 16, 'max_bin': 254, 'lambda_l1': 0.006482691488097224, 'lambda_l2': 0.030842257594925752, 'min_data_in_leaf': 410, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.20249589093597595, 'feature_fraction': 0.7358071260601102, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:35,818] Finished trial#46 with value: 0.22092658226241424 with parameters: {'num_leaves': 64, 'max_bin': 254, 'lambda_l1': 1.6557401998663406, 'lambda_l2': 0.0011198298989840573, 'min_data_in_leaf': 146, 'class_weight': None, 'boosting_type': 'dart', 'learning_rate': 0.09561987871045938, 'feature_fraction': 0.42807450082907333, 'bagging_freq': 2, 'subsample': 0.9581214544580795}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:37,318] Finished trial#47 with value: 0.22092658226241424 with parameters: {'num_leaves': 72, 'max_bin': 254, 'lambda_l1': 2.273446410858789e-08, 'lambda_l2': 0.0005577186212596966, 'min_data_in_leaf': 63, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.08672532878609265, 'feature_fraction': 0.760023163493579, 'bagging_freq': 2, 'subsample': 0.7864143359593331}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:38,774] Finished trial#48 with value: 0.22092658226241424 with parameters: {'num_leaves': 104, 'max_bin': 254, 'lambda_l1': 0.3116387965429042, 'lambda_l2': 1.9914408091816324e-05, 'min_data_in_leaf': 23, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.11542315662747057, 'feature_fraction': 0.5783478111314774, 'bagging_freq': 1}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:40,226] Finished trial#49 with value: 0.22092658226241424 with parameters: {'num_leaves': 88, 'max_bin': 254, 'lambda_l1': 7.879201072905588, 'lambda_l2': 6.439211600448956e-05, 'min_data_in_leaf': 41, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.10594865404915559, 'feature_fraction': 0.447647422855659, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:41,702] Finished trial#50 with value: 0.22092658226241424 with parameters: {'num_leaves': 140, 'max_bin': 254, 'lambda_l1': 0.37205729323488107, 'lambda_l2': 0.00013587942756306855, 'min_data_in_leaf': 360, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.06373734629947342, 'feature_fraction': 0.6904755771990154, 'bagging_freq': 4, 'subsample': 0.9230897032372647}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:43,149] Finished trial#51 with value: 0.22092658226241424 with parameters: {'num_leaves': 64, 'max_bin': 254, 'lambda_l1': 0.10384389686639041, 'lambda_l2': 0.2146844399113301, 'min_data_in_leaf': 372, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.13176121657839873, 'feature_fraction': 0.49029093372444926, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:44,611] Finished trial#52 with value: 0.22092658226241424 with parameters: {'num_leaves': 92, 'max_bin': 254, 'lambda_l1': 2.062169329977396, 'lambda_l2': 1.4648803889313035e-05, 'min_data_in_leaf': 45, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.07002051067262795, 'feature_fraction': 0.4643051532567491, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:46,120] Finished trial#53 with value: 0.22092658226241424 with parameters: {'num_leaves': 100, 'max_bin': 254, 'lambda_l1': 0.6451659095530942, 'lambda_l2': 3.207210252432154e-05, 'min_data_in_leaf': 55, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.05167728916946815, 'feature_fraction': 0.4812064684950697, 'bagging_freq': 1}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:47,598] Finished trial#54 with value: 0.22092658226241424 with parameters: {'num_leaves': 112, 'max_bin': 254, 'lambda_l1': 1.9080715933724106, 'lambda_l2': 4.647891508371892e-06, 'min_data_in_leaf': 27, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.05279830018031468, 'feature_fraction': 0.5220351735418522, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:49,064] Finished trial#55 with value: 0.22092658226241424 with parameters: {'num_leaves': 112, 'max_bin': 254, 'lambda_l1': 0.896787138667522, 'lambda_l2': 2.351155709662661e-07, 'min_data_in_leaf': 22, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.056710400901342224, 'feature_fraction': 0.4026211316795088, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:50,512] Finished trial#56 with value: 0.22092658226241424 with parameters: {'num_leaves': 28, 'max_bin': 254, 'lambda_l1': 0.010809932113884289, 'lambda_l2': 2.4383208116384437e-06, 'min_data_in_leaf': 96, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.07726584372740618, 'feature_fraction': 0.5155273263505584, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:51,974] Finished trial#57 with value: 0.22092658226241424 with parameters: {'num_leaves': 24, 'max_bin': 254, 'lambda_l1': 0.016611816435268562, 'lambda_l2': 9.001289273441228e-07, 'min_data_in_leaf': 94, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.0666348520737729, 'feature_fraction': 0.5123587758657973, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:53,452] Finished trial#58 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 8.577103376527748e-07, 'lambda_l2': 0.0017324763958117089, 'min_data_in_leaf': 211, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.07712712372531703, 'feature_fraction': 0.8554374719361492, 'bagging_freq': 7, 'subsample': 0.9984753888505561}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:54,931] Finished trial#59 with value: 0.22092658226241424 with parameters: {'num_leaves': 132, 'max_bin': 254, 'lambda_l1': 7.488563477032035e-08, 'lambda_l2': 4.977890821770577e-05, 'min_data_in_leaf': 184, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.0846107333929772, 'feature_fraction': 0.8636395707216871, 'bagging_freq': 6, 'subsample': 0.999476075485677}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:56,441] Finished trial#60 with value: 0.22092658226241424 with parameters: {'num_leaves': 28, 'max_bin': 254, 'lambda_l1': 5.726135451863801e-07, 'lambda_l2': 0.00038544633107186335, 'min_data_in_leaf': 208, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.1315628323040401, 'feature_fraction': 0.976155054427742, 'bagging_freq': 5, 'subsample': 0.9072827280830139}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:57,988] Finished trial#61 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 4.493216834905783e-06, 'lambda_l2': 0.005771398676564275, 'min_data_in_leaf': 187, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14730125208855865, 'feature_fraction': 0.9501522240596648, 'bagging_freq': 7, 'subsample': 0.8985241535532429}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:58:59,514] Finished trial#62 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 0.0007570329652851869, 'lambda_l2': 0.0005219558870779001, 'min_data_in_leaf': 236, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.11821201872509203, 'feature_fraction': 0.8771625963452909, 'bagging_freq': 6, 'subsample': 0.9897401978376086}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:01,051] Finished trial#63 with value: 0.22092658226241424 with parameters: {'num_leaves': 48, 'max_bin': 254, 'lambda_l1': 2.633151037519236e-05, 'lambda_l2': 0.0030416702616255266, 'min_data_in_leaf': 241, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.14264237437172486, 'feature_fraction': 0.8382248289900631, 'bagging_freq': 7, 'subsample': 0.6263517586842309}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:02,590] Finished trial#64 with value: 0.22092658226241424 with parameters: {'num_leaves': 76, 'max_bin': 254, 'lambda_l1': 9.32992666948461e-05, 'lambda_l2': 5.817537197470381e-08, 'min_data_in_leaf': 248, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.16489148903891407, 'feature_fraction': 0.9083313465897633, 'bagging_freq': 7, 'subsample': 0.7118096826938589}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:04,141] Finished trial#65 with value: 0.22092658226241424 with parameters: {'num_leaves': 84, 'max_bin': 254, 'lambda_l1': 6.43206573758675e-05, 'lambda_l2': 2.4774018080971625, 'min_data_in_leaf': 165, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.18126541326461992, 'feature_fraction': 0.8142204018262563, 'bagging_freq': 7, 'subsample': 0.6326628331493699}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:05,686] Finished trial#66 with value: 0.22092658226241424 with parameters: {'num_leaves': 60, 'max_bin': 254, 'lambda_l1': 1.632685175464277e-05, 'lambda_l2': 0.7268562858361227, 'min_data_in_leaf': 306, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.16836157052391185, 'feature_fraction': 0.6632066837599196, 'bagging_freq': 5, 'subsample': 0.8841629508056328}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:07,269] Finished trial#67 with value: 0.22092658226241424 with parameters: {'num_leaves': 60, 'max_bin': 254, 'lambda_l1': 5.581624376518548e-06, 'lambda_l2': 9.013108078361054, 'min_data_in_leaf': 481, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.15286361319687541, 'feature_fraction': 0.6248737602365464, 'bagging_freq': 6, 'subsample': 0.8685674376137645}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:08,729] Finished trial#68 with value: 0.22092658226241424 with parameters: {'num_leaves': 72, 'max_bin': 254, 'lambda_l1': 0.0003261269725930478, 'lambda_l2': 2.8293566700932526, 'min_data_in_leaf': 462, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.19340140280651189, 'feature_fraction': 0.5609599065458338, 'bagging_freq': 7, 'subsample': 0.9425464600641303}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:10,199] Finished trial#69 with value: 0.22092658226241424 with parameters: {'num_leaves': 84, 'max_bin': 254, 'lambda_l1': 2.0675153165754007e-06, 'lambda_l2': 1.2252548389308788, 'min_data_in_leaf': 313, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.22991863704885068, 'feature_fraction': 0.5431886843914329, 'bagging_freq': 5, 'subsample': 0.7959216206777483}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:11,676] Finished trial#70 with value: 0.22092658226241424 with parameters: {'num_leaves': 48, 'max_bin': 254, 'lambda_l1': 0.00019059563448067958, 'lambda_l2': 0.024493367982641127, 'min_data_in_leaf': 135, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.2250608164948169, 'feature_fraction': 0.7175563027837851, 'bagging_freq': 7, 'subsample': 0.9657700592223044}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:13,167] Finished trial#71 with value: 0.22092658226241424 with parameters: {'num_leaves': 156, 'max_bin': 254, 'lambda_l1': 7.667060758388681, 'lambda_l2': 6.167578564699181e-05, 'min_data_in_leaf': 406, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.10644263779919479, 'feature_fraction': 0.7603035269203091, 'bagging_freq': 1, 'subsample': 0.7668186770907572}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:14,643] Finished trial#72 with value: 0.22092658226241424 with parameters: {'num_leaves': 176, 'max_bin': 254, 'lambda_l1': 2.707328647555433, 'lambda_l2': 0.00014127277035790573, 'min_data_in_leaf': 41, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.070566414286151, 'feature_fraction': 0.45223040858657915, 'bagging_freq': 1, 'subsample': 0.594814187411659}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:16,110] Finished trial#73 with value: 0.22092658226241424 with parameters: {'num_leaves': 92, 'max_bin': 254, 'lambda_l1': 0.15205237114102554, 'lambda_l2': 1.5158204034657326e-05, 'min_data_in_leaf': 66, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.09747174833049459, 'feature_fraction': 0.75860371401601, 'bagging_freq': 2, 'subsample': 0.5195494059029253}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:17,629] Finished trial#74 with value: 0.22092658226241424 with parameters: {'num_leaves': 100, 'max_bin': 254, 'lambda_l1': 0.3788812148681935, 'lambda_l2': 3.211665343139116e-05, 'min_data_in_leaf': 358, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.08586115014198387, 'feature_fraction': 0.48135167447684035, 'bagging_freq': 1}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:19,109] Finished trial#75 with value: 0.22092658226241424 with parameters: {'num_leaves': 108, 'max_bin': 254, 'lambda_l1': 3.758528707638883, 'lambda_l2': 0.00010970788724157733, 'min_data_in_leaf': 48, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.062871316321964, 'feature_fraction': 0.464002855494604, 'bagging_freq': 1}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:20,574] Finished trial#76 with value: 0.22092658226241424 with parameters: {'num_leaves': 140, 'max_bin': 254, 'lambda_l1': 7.795390010143934, 'lambda_l2': 4.198355790865375e-06, 'min_data_in_leaf': 36, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.050148203518752724, 'feature_fraction': 0.6832519477919531, 'bagging_freq': 1}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:22,024] Finished trial#77 with value: 0.22092658226241424 with parameters: {'num_leaves': 124, 'max_bin': 254, 'lambda_l1': 2.1350579989882736, 'lambda_l2': 1.0729662608333683e-05, 'min_data_in_leaf': 357, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.0544425772409913, 'feature_fraction': 0.49591539063658807, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:23,492] Finished trial#78 with value: 0.22092658226241424 with parameters: {'num_leaves': 112, 'max_bin': 254, 'lambda_l1': 0.7038588350595677, 'lambda_l2': 4.243133143882653e-07, 'min_data_in_leaf': 53, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.052370453161655825, 'feature_fraction': 0.4083864585381991, 'bagging_freq': 2}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:24,964] Finished trial#79 with value: 0.22092658226241424 with parameters: {'num_leaves': 116, 'max_bin': 254, 'lambda_l1': 0.1094918153512276, 'lambda_l2': 4.811083547485763e-06, 'min_data_in_leaf': 102, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.05684893490042888, 'feature_fraction': 0.5260220865348755, 'bagging_freq': 3}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:26,465] Finished trial#80 with value: 0.22092658226241424 with parameters: {'num_leaves': 104, 'max_bin': 254, 'lambda_l1': 0.014000342052366712, 'lambda_l2': 1.5435331533356686e-06, 'min_data_in_leaf': 95, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.07092007899732335, 'feature_fraction': 0.526850878785086, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:28,013] Finished trial#81 with value: 0.22092658226241424 with parameters: {'num_leaves': 120, 'max_bin': 254, 'lambda_l1': 0.07649595850116332, 'lambda_l2': 2.509602358557819e-07, 'min_data_in_leaf': 80, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.06690406703293814, 'feature_fraction': 0.5164446728542248, 'bagging_freq': 4}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:29,561] Finished trial#82 with value: 0.22092658226241424 with parameters: {'num_leaves': 132, 'max_bin': 254, 'lambda_l1': 5.958399814629976e-08, 'lambda_l2': 1.4649718202311868e-06, 'min_data_in_leaf': 215, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.07592581392367857, 'feature_fraction': 0.8563679062642108, 'bagging_freq': 4, 'subsample': 0.782528529465877}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:31,118] Finished trial#83 with value: 0.22092658226241424 with parameters: {'num_leaves': 152, 'max_bin': 254, 'lambda_l1': 1.2734241179416544e-08, 'lambda_l2': 8.583814977888008e-08, 'min_data_in_leaf': 58, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.060305220327403354, 'feature_fraction': 0.8427300572458599, 'bagging_freq': 2, 'subsample': 0.7303312052280099}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:32,680] Finished trial#84 with value: 0.22092658226241424 with parameters: {'num_leaves': 28, 'max_bin': 254, 'lambda_l1': 4.876210111096335e-07, 'lambda_l2': 5.218300595837359e-07, 'min_data_in_leaf': 213, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.08337181678219657, 'feature_fraction': 0.40072459675648125, 'bagging_freq': 5, 'subsample': 0.9760404455696227}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:34,237] Finished trial#85 with value: 0.22092658226241424 with parameters: {'num_leaves': 24, 'max_bin': 254, 'lambda_l1': 1.227350113933533e-07, 'lambda_l2': 9.499472625050188e-07, 'min_data_in_leaf': 163, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.055810566716898304, 'feature_fraction': 0.8859584853633479, 'bagging_freq': 6, 'subsample': 0.9306892133553784}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:35,787] Finished trial#86 with value: 0.22092658226241424 with parameters: {'num_leaves': 32, 'max_bin': 254, 'lambda_l1': 7.870851645887944e-07, 'lambda_l2': 3.0172625577167795e-06, 'min_data_in_leaf': 190, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13121303409297624, 'feature_fraction': 0.9536120283640273, 'bagging_freq': 6, 'subsample': 0.9235449021322806}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:37,348] Finished trial#87 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 3.0789749359041063e-06, 'lambda_l2': 0.0006524556377054193, 'min_data_in_leaf': 200, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.123944002236402, 'feature_fraction': 0.8804723176647714, 'bagging_freq': 6, 'subsample': 0.9499157980593778}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:38,853] Finished trial#88 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 2.3896609848177904e-05, 'lambda_l2': 0.0018309935698839787, 'min_data_in_leaf': 229, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.14536914896338712, 'feature_fraction': 0.9334948019859073, 'bagging_freq': 7, 'subsample': 0.9946476223344124}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:40,312] Finished trial#89 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 0.001313252827694635, 'lambda_l2': 0.0022680901043998464, 'min_data_in_leaf': 224, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.14086208177779558, 'feature_fraction': 0.8332150768742892, 'bagging_freq': 7, 'subsample': 0.9005599437597778}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:41,810] Finished trial#90 with value: 0.22092658226241424 with parameters: {'num_leaves': 52, 'max_bin': 254, 'lambda_l1': 1.185529899625198e-06, 'lambda_l2': 0.0002528490833661314, 'min_data_in_leaf': 256, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.14040577079568317, 'feature_fraction': 0.9015985154812959, 'bagging_freq': 7, 'subsample': 0.907698012672985}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:43,277] Finished trial#91 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 6.866995811269678e-05, 'lambda_l2': 1.324480818776973e-08, 'min_data_in_leaf': 264, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.1768784849264863, 'feature_fraction': 0.8778935127666425, 'bagging_freq': 7, 'subsample': 0.8893259703299177}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:44,758] Finished trial#92 with value: 0.22092658226241424 with parameters: {'num_leaves': 56, 'max_bin': 254, 'lambda_l1': 2.3709226603290134e-05, 'lambda_l2': 0.6159233994575575, 'min_data_in_leaf': 300, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.16830418581208037, 'feature_fraction': 0.8051365325861891, 'bagging_freq': 7, 'subsample': 0.99537852611545}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:46,243] Finished trial#93 with value: 0.22092658226241424 with parameters: {'num_leaves': 48, 'max_bin': 254, 'lambda_l1': 5.328946587963534e-06, 'lambda_l2': 0.0073455353024376715, 'min_data_in_leaf': 182, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.1868501420926374, 'feature_fraction': 0.8218447542078081, 'bagging_freq': 7, 'subsample': 0.9814998484231188}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:47,768] Finished trial#94 with value: 0.22092658226241424 with parameters: {'num_leaves': 64, 'max_bin': 254, 'lambda_l1': 4.9310023723928755e-06, 'lambda_l2': 0.0004643287011446208, 'min_data_in_leaf': 166, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.15303746011047667, 'feature_fraction': 0.6470191629913435, 'bagging_freq': 6, 'subsample': 0.6167596481788726}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:49,249] Finished trial#95 with value: 0.22092658226241424 with parameters: {'num_leaves': 76, 'max_bin': 254, 'lambda_l1': 0.0002493195254542579, 'lambda_l2': 3.463108320540521, 'min_data_in_leaf': 256, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.16453024251623938, 'feature_fraction': 0.9760063280140611, 'bagging_freq': 7, 'subsample': 0.6503155163770845}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:50,710] Finished trial#96 with value: 0.22092658226241424 with parameters: {'num_leaves': 84, 'max_bin': 254, 'lambda_l1': 2.08231535975494e-06, 'lambda_l2': 3.4889752813420585, 'min_data_in_leaf': 301, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.18299844570313406, 'feature_fraction': 0.5653584250779492, 'bagging_freq': 7, 'subsample': 0.721456930563716}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:52,166] Finished trial#97 with value: 0.22092658226241424 with parameters: {'num_leaves': 60, 'max_bin': 254, 'lambda_l1': 9.769088953539289e-05, 'lambda_l2': 0.45627958736805135, 'min_data_in_leaf': 244, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.1528719014611931, 'feature_fraction': 0.6271406068639138, 'bagging_freq': 7, 'subsample': 0.6153456820250548}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:53,653] Finished trial#98 with value: 0.22092658226241424 with parameters: {'num_leaves': 72, 'max_bin': 254, 'lambda_l1': 0.00027776614050504524, 'lambda_l2': 2.9310462711224092, 'min_data_in_leaf': 307, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.23267222130521872, 'feature_fraction': 0.71477590939893, 'bagging_freq': 6, 'subsample': 0.6338261924316267}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:55,144] Finished trial#99 with value: 0.22092658226241424 with parameters: {'num_leaves': 84, 'max_bin': 254, 'lambda_l1': 4.8336851024747234e-05, 'lambda_l2': 0.0629898540364416, 'min_data_in_leaf': 452, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.19336385266560846, 'feature_fraction': 0.7838779798666848, 'bagging_freq': 7, 'subsample': 0.664559447917736}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:56,605] Finished trial#100 with value: 0.22092658226241424 with parameters: {'num_leaves': 192, 'max_bin': 254, 'lambda_l1': 8.806766970202661e-06, 'lambda_l2': 6.6228878821947665, 'min_data_in_leaf': 484, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.20828167387304614, 'feature_fraction': 0.6700120764573645, 'bagging_freq': 5, 'subsample': 0.6285128791929391}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:58,200] Finished trial#101 with value: 0.22092658226241424 with parameters: {'num_leaves': 176, 'max_bin': 254, 'lambda_l1': 1.759524595197846e-05, 'lambda_l2': 0.9198449708482572, 'min_data_in_leaf': 420, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.17373234705918808, 'feature_fraction': 0.7704883253273797, 'bagging_freq': 7, 'subsample': 0.5780974558538179}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 17:59:59,738] Finished trial#102 with value: 0.22092658226241424 with parameters: {'num_leaves': 76, 'max_bin': 254, 'lambda_l1': 3.7834985208799095e-05, 'lambda_l2': 0.0001638293095515823, 'min_data_in_leaf': 133, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.10186844780743516, 'feature_fraction': 0.7471622790016111, 'bagging_freq': 5, 'subsample': 0.6817900316989327}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:00:01,299] Finished trial#103 with value: 0.22092658226241424 with parameters: {'num_leaves': 96, 'max_bin': 254, 'lambda_l1': 4.55076777824493, 'lambda_l2': 5.467162578991973e-05, 'min_data_in_leaf': 339, 'class_weight': 'balanced', 'boosting_type': 'dart', 'learning_rate': 0.10862950047216656, 'feature_fraction': 0.7134258154527013, 'bagging_freq': 1, 'subsample': 0.8702805318142861}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:00:02,855] Finished trial#104 with value: 0.22092658226241424 with parameters: {'num_leaves': 176, 'max_bin': 254, 'lambda_l1': 3.64344623868563, 'lambda_l2': 9.706143098791175e-05, 'min_data_in_leaf': 409, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.10183422633661088, 'feature_fraction': 0.5415506174882732, 'bagging_freq': 1, 'subsample': 0.8215862955535411}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:00:04,396] Finished trial#105 with value: 0.22092658226241424 with parameters: {'num_leaves': 160, 'max_bin': 254, 'lambda_l1': 1.5849092551437693e-06, 'lambda_l2': 2.8043215385585803e-05, 'min_data_in_leaf': 316, 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'learning_rate': 0.23083066357997, 'feature_fraction': 0.4582558539818594, 'bagging_freq': 1, 'subsample': 0.8086505067551827}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:00:05,946] Finished trial#106 with value: 0.22092658226241424 with parameters: {'num_leaves': 92, 'max_bin': 254, 'lambda_l1': 9.173060047713346, 'lambda_l2': 7.445084544449785e-06, 'min_data_in_leaf': 69, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.0878430534603474, 'feature_fraction': 0.7011918237196522, 'bagging_freq': 1, 'subsample': 0.8748561859405067}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:00:07,505] Finished trial#107 with value: 0.22092658226241424 with parameters: {'num_leaves': 148, 'max_bin': 254, 'lambda_l1': 3.2609826523430523, 'lambda_l2': 6.897544880615673e-06, 'min_data_in_leaf': 350, 'class_weight': None, 'boosting_type': 'goss', 'learning_rate': 0.07234471683387618, 'feature_fraction': 0.4420470082614347, 'bagging_freq': 1}. Best is trial#0 with value: 0.22092658226241424.
# ...
# [I 2020-04-02 18:53:35,711] Finished trial#1851 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.1046441356237543e-06, 'lambda_l2': 0.003422689073879694, 'min_data_in_leaf': 225, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13470141159858184, 'feature_fraction': 0.9999670378642023, 'bagging_freq': 3, 'subsample': 0.5758871858175031}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:37,940] Finished trial#1852 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.7160080306265904e-06, 'lambda_l2': 0.004040807355142393, 'min_data_in_leaf': 224, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13013313279940344, 'feature_fraction': 0.9996100801971177, 'bagging_freq': 3, 'subsample': 0.5813799565275413}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:40,164] Finished trial#1853 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 1.7333571973049734e-06, 'lambda_l2': 0.0028900165846427266, 'min_data_in_leaf': 225, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.12812205418397618, 'feature_fraction': 0.9887806985937239, 'bagging_freq': 3, 'subsample': 0.5885736270310562}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:42,342] Finished trial#1854 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.9835832934419994e-06, 'lambda_l2': 0.0037679648418578885, 'min_data_in_leaf': 225, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13567495331144722, 'feature_fraction': 0.9877598406887151, 'bagging_freq': 3, 'subsample': 0.5736046713052032}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:44,543] Finished trial#1855 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 1.2402347149433386e-06, 'lambda_l2': 0.0028663939939871006, 'min_data_in_leaf': 220, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13384396215250158, 'feature_fraction': 0.9997981614044512, 'bagging_freq': 3, 'subsample': 0.585239365733623}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:46,669] Finished trial#1856 with value: 0.22092658226241424 with parameters: {'num_leaves': 36, 'max_bin': 254, 'lambda_l1': 1.8469191815782665e-06, 'lambda_l2': 0.004557315491929258, 'min_data_in_leaf': 227, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13674447977443308, 'feature_fraction': 0.9996325440385512, 'bagging_freq': 3, 'subsample': 0.5949968088238163}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:48,778] Finished trial#1857 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 2.076026788293695e-06, 'lambda_l2': 0.003966108179726767, 'min_data_in_leaf': 223, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13683096366212008, 'feature_fraction': 0.9871148949931781, 'bagging_freq': 3, 'subsample': 0.5889267570188873}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:50,882] Finished trial#1858 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 2.1317275796352104e-06, 'lambda_l2': 0.002329980047976516, 'min_data_in_leaf': 230, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13623812699556787, 'feature_fraction': 0.9849681448682973, 'bagging_freq': 3, 'subsample': 0.595377037607969}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:52,928] Finished trial#1859 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 2.4545906288241873e-06, 'lambda_l2': 0.003457925968344007, 'min_data_in_leaf': 232, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13785720012560415, 'feature_fraction': 0.999597018751448, 'bagging_freq': 3, 'subsample': 0.5795441635958113}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:55,018] Finished trial#1860 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.4758763638904117e-06, 'lambda_l2': 0.0024105841818300154, 'min_data_in_leaf': 230, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13466477766503177, 'feature_fraction': 0.9970868961593354, 'bagging_freq': 3, 'subsample': 0.5922222680193998}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:57,206] Finished trial#1861 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 2.0382941601460632e-06, 'lambda_l2': 0.002296367911610006, 'min_data_in_leaf': 232, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.1364704718109038, 'feature_fraction': 0.9990007205697327, 'bagging_freq': 3, 'subsample': 0.5995225149621299}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:53:59,279] Finished trial#1862 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 2.6358580794477748e-06, 'lambda_l2': 0.002259865593649483, 'min_data_in_leaf': 232, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13802460800328195, 'feature_fraction': 0.9857552389758579, 'bagging_freq': 3, 'subsample': 0.5912376496612038}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:01,396] Finished trial#1863 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.4814282585221068e-06, 'lambda_l2': 0.004719441298996528, 'min_data_in_leaf': 233, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13791318613889347, 'feature_fraction': 0.9989159972807657, 'bagging_freq': 3, 'subsample': 0.5988612304540623}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:03,575] Finished trial#1864 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 1.7387377409252375e-06, 'lambda_l2': 0.003762779721089706, 'min_data_in_leaf': 233, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13926939838988495, 'feature_fraction': 0.9860324345886365, 'bagging_freq': 3, 'subsample': 0.6037972753287731}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:05,789] Finished trial#1865 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 2.5362116660268214e-06, 'lambda_l2': 0.0022851880439514393, 'min_data_in_leaf': 228, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.1338211244232855, 'feature_fraction': 0.9988878329763001, 'bagging_freq': 3, 'subsample': 0.5971598200852564}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:07,976] Finished trial#1866 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 1.6201982121711367e-06, 'lambda_l2': 0.0050476042652551996, 'min_data_in_leaf': 235, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13887538613122521, 'feature_fraction': 0.9847120285873586, 'bagging_freq': 3, 'subsample': 0.603424680590199}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:10,186] Finished trial#1867 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 1.8657259714397019e-06, 'lambda_l2': 0.004238956953505851, 'min_data_in_leaf': 234, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13889647048706533, 'feature_fraction': 0.9813399354081125, 'bagging_freq': 3, 'subsample': 0.5982173969845245}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:12,356] Finished trial#1868 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 3.2994644155570793e-06, 'lambda_l2': 0.004801843702407117, 'min_data_in_leaf': 237, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13929608161097767, 'feature_fraction': 0.988461837980596, 'bagging_freq': 3, 'subsample': 0.5861374173835071}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:14,541] Finished trial#1869 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 3.4229441494801917e-06, 'lambda_l2': 0.006429333366170994, 'min_data_in_leaf': 235, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14077901661466521, 'feature_fraction': 0.9785587827539496, 'bagging_freq': 3, 'subsample': 0.5885190043964712}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:16,684] Finished trial#1870 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 2.825119831239923e-06, 'lambda_l2': 0.005492761526573777, 'min_data_in_leaf': 236, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.137225237632977, 'feature_fraction': 0.9974799586865432, 'bagging_freq': 3, 'subsample': 0.6085850288300269}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:18,802] Finished trial#1871 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 2.6006638241015864e-06, 'lambda_l2': 0.006252944376927133, 'min_data_in_leaf': 239, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14088906481687294, 'feature_fraction': 0.9989030823836634, 'bagging_freq': 3, 'subsample': 0.608061234329971}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:20,934] Finished trial#1872 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 3.48014897196353e-06, 'lambda_l2': 0.0025263056835544, 'min_data_in_leaf': 240, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14108947057974702, 'feature_fraction': 0.9992524595701943, 'bagging_freq': 3, 'subsample': 0.6067746171539902}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:23,029] Finished trial#1873 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 2.0146104450775177e-06, 'lambda_l2': 0.0042999889793139175, 'min_data_in_leaf': 238, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.13953678141064463, 'feature_fraction': 0.9880916026642704, 'bagging_freq': 3, 'subsample': 0.6107882638147581}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:25,148] Finished trial#1874 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 3.319495153174326e-06, 'lambda_l2': 0.007369473327038715, 'min_data_in_leaf': 239, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14170916018900595, 'feature_fraction': 0.9998912783857788, 'bagging_freq': 3, 'subsample': 0.6131981291898287}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:27,256] Finished trial#1875 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 3.1654827725101656e-06, 'lambda_l2': 0.007239139447808481, 'min_data_in_leaf': 233, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14307987857400917, 'feature_fraction': 0.985790052589517, 'bagging_freq': 3, 'subsample': 0.5994400350812666}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:29,341] Finished trial#1876 with value: 0.22092658226241424 with parameters: {'num_leaves': 44, 'max_bin': 254, 'lambda_l1': 4.384835599261577e-06, 'lambda_l2': 0.004744909706458761, 'min_data_in_leaf': 241, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14336869396257132, 'feature_fraction': 0.9785886716115673, 'bagging_freq': 3, 'subsample': 0.6166389523009169}. Best is trial#0 with value: 0.22092658226241424.
# [I 2020-04-02 18:54:31,534] Finished trial#1877 with value: 0.22092658226241424 with parameters: {'num_leaves': 40, 'max_bin': 254, 'lambda_l1': 3.1632763640432153e-06, 'lambda_l2': 0.002812350110836411, 'min_data_in_leaf': 240, 'class_weight': None, 'boosting_type': 'gbdt', 'learning_rate': 0.14349578353366566, 'feature_fraction': 0.9797735450378352, 'bagging_freq': 3, 'subsample': 0.6020477842484924}. Best is trial#0 with value: 0.22092658226241424.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-804ea67e1e3d> in <module>()
#      76 study = optuna.create_study(direction='minimize')
#      77
# ---> 78 study.optimize(objective, n_trials=5000)
#
# /usr/local/lib/python3.6/dist-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     329             if n_jobs == 1:
#     330                 self._optimize_sequential(
# --> 331                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     332                 )
#     333             else:
#
# /usr/local/lib/python3.6/dist-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     624                     break
#     625
# --> 626             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     627
#     628             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# /usr/local/lib/python3.6/dist-packages/optuna/study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     654         # type: (...) -> None
#     655
# --> 656         trial = self._run_trial(func, catch, gc_after_trial)
#     657         if callbacks is not None:
#     658             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# /usr/local/lib/python3.6/dist-packages/optuna/study.py in _run_trial(self, func, catch, gc_after_trial)
#     675
#     676         try:
# --> 677             result = func(trial)
#     678         except exceptions.TrialPruned as e:
#     679             message = "Setting status of trial#{} as {}. {}".format(
#
# <ipython-input-81-804ea67e1e3d> in objective(trial)
#      40
#      41     cv_results = lgb.cv(params, train_set, num_boost_round = 10000, nfold = 3,
# ---> 42                         early_stopping_rounds = 100, metrics = 'auc', seed = 50)
#      43
#      44     run_time = timer() - start
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py in cv(params, train_set, num_boost_round, folds, nfold, stratified, shuffle, metrics, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, fpreproc, verbose_eval, show_stdv, seed, callbacks)
#     485                                     end_iteration=num_boost_round,
#     486                                     evaluation_result_list=None))
# --> 487         cvfolds.update(fobj=fobj)
#     488         res = _agg_cv_result(cvfolds.eval_valid(feval))
#     489         for _, key, mean, _, std in res:
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py in handler_function(*args, **kwargs)
#     261             ret = []
#     262             for booster in self.boosters:
# --> 263                 ret.append(getattr(booster, name)(*args, **kwargs))
#     264             return ret
#     265         return handler_function
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# # LGBM Class

# %%
class LightGBM_Class():
  def __init__(self, df, target):
    self.df = df
    self.target = target
    self.train_set = lgb.Dataset(data=self.df, label = self.target)

  
  def lgbm_classifier(self, num_round = 10, nfold = 5):
    self.param = {'num_leaves': 31, 'objective': 'binary'}
    self.param['metric'] = 'auc'
    self.num_round =  num_round
    self.n_fold = nfold
    bst = lgb.LGBMClassifier()
    bst.fit(self.df, self.target)
    return bst

# %%
test = LightGBM_Class(train_X, train_y)

# %%
model = test.lgbm_classifier()

# %%
model.save_model('model.txt', num_iteration = model.best_iteration)

# %%
model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
ml = lgb.(params, train_set)

# %%
params
# Out:
# {'bagging_freq': 3,
#  'boosting_type': 'gbdt',
#  'class_weight': 'balanced',
#  'feature_fraction': 0.48571428571428577,
#  'lambda_l1': 0.18367346938775508,
#  'lambda_l2': 0.6938775510204082,
#  'learning_rate': 0.15731471815103718,
#  'max_bin': 254,
#  'min_data_in_leaf': 320,
#  'num_leaves': 96,
#  'subsample': 0.9595959595959596,
#  'verbosity': 0}
